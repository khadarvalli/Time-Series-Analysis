# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanappa/Time-Series-Analysis-Projects-/blob/master/Time_Series_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Concepts In Time-Series
#
# - Trends.
# - Seasonality.
# - Cyclic.
# - Statinary.
#
# Talking about various modelling techniques ARIMA ,Fbprofit and LSTM modelling In this we will cover about various modelling technique focus on giving an overview about concept of time Series.
#
# Time Series is simply a series of data point order in time now when forecasting time series data the given is to estimate how the sequence of observation will continue in the future if you are running on IoT sensor or something like that the data is coming continuous sneezing continuously what is talking about whether data maybe you get weather updates every hour or even every 10 minutes 20 minutes we talking about smart electric metres  you may get it every 15 minutes 30 minutes depending on the source of generation you may have a variable frequency at which the data is collected right now the measured as a function of time series is it assume that the past pattern and behaviour will continue the future and thus the main subject that you made your modelling time-series data
#
# I want to take data from the car which will give a recent data continuously and sent it to a centralized location like an activity that the at various points at this time and energy forecasting is select one the sum of the use cases energy forecast in typically want to sketch pad are typically want to understand the user demand for electricity and accordingly a manager production or if you are overproducing it will want to sell in an open market at these are some of the examples of time series data.
#
#  Whenever we talk about the time-series data that there are some key concepts that we need to understand the data can have certain seasonality, trend data that generated with some cyclic Pattern.
#
# # Trends
#
# The first concept about the Time Series Analysis is nothing but the trends.
# We will see the concept in the future about Statistical Techniques that can be used to identify as a Trend or seasonality all in one stage of the data stationary or not.
# So let's start with Trend so basically when trend exists when we say a long term decrease and increase in the data if see the graph, This is an international air travel series. If we see the data is continuously increasing from 1949 to 1961.
# They had traveled pattern has been continuously receiving and along with increasing seasonality also.
#
# In every time series, the travel of data moves from  ups and down.
# sometimes the time series is started from small and low position then starts to increase along time.
#
# On the other hand, it can go reverse.
# In every trend, there is some pattern involve like increase then flattens and then again increment with same..

# %%
from IPython.display import Image
Image('/content/Capture.JPG')

# %% [markdown]
# ## Seasonality
#
# Data now a seasonal pattern occurs when a time series is affected by typically a regular according Pattern.
#
# Like every month or every weak the sales will get increase.
#
# That is showing the seasonality in the time-Series-analysis.
#
# Every winter season the sales of the sweater will get increase that kind of seasonality we can seen inside data.
#
#
# In every deeewali the fire-craker sales will get incrase.That kind of seasonality I wanted to say.
#
# If the high sales is happened in the month of November of year and that's happening every november month of year.That time say there is fixed seasonal avalible.
#
# If in the other term the cyclic pattern is the movemnet we can predict by watching your last seasonality of data.
# ex.Directly import duties increase and the cloths price got increase and gold price is also get increase.
#
# This is like we can cyclic in nature.

# %%
from IPython.display import Image
Image('/content/Capture.JPG')

# %% [markdown]
# In the above we can see there are four types of seasonalities are avalible:-
# - Additive Seasonality :- In this magnitude is peaks of evey year is well maintained at constant from  the mean of that series.
#
# - Multiplicative Seasonality.:-n this magnitude is peaks of evey year is not well maintained at constant from  the mean of that series.
#
# It can further classified with trend series and no-trend series.
#
#  Data Rise of the fall is not fixed the nature right then typically what we call it is cyclic and noncyclic can happen because of some the suicide does or economic cycles this is more seasonality retail Industry  like a larger demand and larger depending on customers than the normal day all of the business to take any electricity consumption little during the weekend that city consumption is higher in the house Because a lot of people tend to stay at home at so so all you had to almost everywhere at the deceased narrative.

# %% [markdown]
# ## Stationary.
#
# - Stationary now when we call the date when we called it a stationary it's basically when the mean is constant when the standard deviation is constant and there is no seasonality or trend.
# - Now the first two are very important that are the mean and variance throughout the series is should be constant.
#
# - There are techniques by which we can make the data stationary but right now.
# This data is fluctuating around its mean and It self-centered around zero.
#
# - you don't see much seasonality, trend.
# There is no any kind of positive or negative seasonality available.
#
# - In order to know if any series is seasonal or not we basically use ADF(Adafuller test).
#
# - Whereas the not-Stationary series is not exactly opposite to the above.
#
# - White Noise:- Points in the series that does not have any auto-correlation called as white noise.
# That points we call as outliers also.
#
#
# - Autocorrelation is a correlation of itself. It means the previous time period is how correlated it is forecasted or present time.

# %%
from IPython.display import Image
Image('/content/Capture.JPG')

# %%
from IPython.display import Image
Image('/content/Capture.JPG')

# %% [markdown]
# ## Thank You !!
